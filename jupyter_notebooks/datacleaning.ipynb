# %% [markdown]
# ## Data cleaning

# %%
import pandas as pd
df = pd.read_csv('../data/trimdata.csv')

# %%
df.head()
# Out:
#    user_id   app_name  age  gender        country urban_rural  income_level  \
# 0  1252559  Instagram   37  Female         Brazil       Urban          High
# 1   332063  Instagram   45  Female        Germany       Urban  Lower-middle
# 2  1459191  Instagram   22    Male        Germany       Urban  Upper-middle
# 3   737622  Instagram   56  Female  United States    Suburban           Low
# 4    67111  Instagram   60    Male  United States       Urban           Low
#
#     employment_status education_level relationship_status  ...  \
# 0             Student    Some college              Single  ...
# 1  Full-time employed     High school             Married  ...
# 2          Freelancer      Bachelor’s   In a relationship  ...
# 3  Full-time employed     High school              Single  ...
# 4  Full-time employed        Master’s              Single  ...
#
#   last_login_date  average_session_length_minutes  content_type_preference  \
# ...

# %%
df.shape
# Out:
# (200, 58)

# %%
df.dtypes
# Out:
# user_id                             int64
# app_name                           object
# age                                 int64
# gender                             object
# country                            object
# urban_rural                        object
# income_level                       object
# employment_status                  object
# education_level                    object
# relationship_status                object
# has_children                       object
# exercise_hours_per_week           float64
# sleep_hours_per_night             float64
# diet_quality                       object
# smoking                            object
# alcohol_frequency                  object
# perceived_stress_score              int64
# self_reported_happiness             int64
# body_mass_index                   float64
# blood_pressure_systolic             int64
# blood_pressure_diastolic            int64
# daily_steps_count                   int64
# ...

# %%
df.drop(columns=['user_id', 'uses_premium_features', 'two_factor_auth_enabled', 'biometric_login_used', 'smoking', 'alcohol_frequency', 'blood_pressure_systolic', 'blood_pressure_diastolic', 'body_mass_index'], inplace=True, errors='ignore')

# %%
df.isnull().sum()
# Out:
# app_name                          0
# age                               0
# gender                            0
# country                           0
# urban_rural                       0
# income_level                      0
# employment_status                 0
# education_level                   0
# relationship_status               0
# has_children                      0
# exercise_hours_per_week           0
# sleep_hours_per_night             0
# diet_quality                      0
# perceived_stress_score            0
# self_reported_happiness           0
# daily_steps_count                 0
# weekly_work_hours                 0
# hobbies_count                     0
# social_events_per_month           0
# books_read_per_year               0
# volunteer_hours_per_month         0
# travel_frequency_per_year         0
# daily_active_minutes_instagram    0
# sessions_per_day                  0
# posts_created_per_week            0
# reels_watched_per_day             0
# ...

# %%
df['relationship_status'].unique()
# Out:
# array(['Single', 'Married', 'In a relationship', 'Divorced', 'Widowed'],
#       dtype=object)

# %%
df.replace({'relationship_status': {'In a relationship': 'Relationship'}}, inplace=True)

# %%
df['relationship_status'].unique()
# Out:
# array(['Single', 'Married', 'Relationship', 'Divorced', 'Widowed'],
#       dtype=object)

# %%
df['app_name'].unique()
# Out:
# array(['Instagram'], dtype=object)

# %%
df.drop(columns=['app_name'], inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('../data/cleaned_data.csv', index=False)
